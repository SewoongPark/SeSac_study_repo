# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "c:/Users/bluecom001/Desktop/pose_estimation/landmarks_csv/walk_man_middle_side.xlsx"
df_side = pd.read_excel(file_path)
df_side.head()
# Out:
#        Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0  9175236225128170     -0.067215      0.349202     -0.057309      0.352014
# 1                 2      0.000000      0.000000      0.003897     -0.020056
# 2                 3      0.000000      0.000000      0.001755     -0.022411
# 3                 4      0.000000      0.000000      0.001272     -0.022627
# 4                 5      0.000000      0.000000      0.003532     -0.022217
#
#    Landmark_5_X  Landmark_6_X  Landmark_7_X  Landmark_8_X  Landmark_9_X  ...  \
# 0     -0.062807      0.561395     -0.049723      0.583561     -0.075712  ...
# 1      0.003212     -0.022263      0.002387     -0.024717      0.003424  ...
# 2      0.003302     -0.024321      0.004938     -0.026362      0.000122  ...
# 3      0.002949     -0.024519      0.004819     -0.026558      0.000364  ...
# 4      0.005427     -0.023734      0.007527     -0.025390      0.002010  ...
#
# ...

# %%
file_path = "./landmarks_csv/walk_man_middle_front.xlsx"
df_front = pd.read_excel(file_path)
df_front.head()
# Out:
#      Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0  57469964027405      0.052122      0.184667     -0.031033      0.185627
# 1               2      0.000000      0.000000      0.009360     -0.007728
# 2               3      0.000000      0.000000      0.009326     -0.008020
# 3               4      0.000000      0.000000      0.009107     -0.008286
# 4               5      0.000000      0.000000      0.008712     -0.008542
#
#    Landmark_5_X  Landmark_6_X  Landmark_7_X  Landmark_8_X  Landmark_9_X  ...  \
# 0      0.041640      0.282604     -0.020170      0.284575      0.023160  ...
# 1      0.015000     -0.007738      0.019660     -0.007533     -0.009993  ...
# 2      0.015185     -0.008055      0.019988     -0.007782     -0.009893  ...
# 3      0.015047     -0.008344      0.020044     -0.008050     -0.009961  ...
# 4      0.014717     -0.008594      0.020119     -0.008330     -0.010189  ...
#
# ...

# %%
landmark_x_columns = df_front.filter(regex='Landmark_\d+_X')
landmark_x_columns
# Out:
#        Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0    57469964027405      0.052122      0.184667     -0.031033      0.185627
# 1                 2      0.000000      0.000000      0.009360     -0.007728
# 2                 3      0.000000      0.000000      0.009326     -0.008020
# 3                 4      0.000000      0.000000      0.009107     -0.008286
# 4                 5      0.000000      0.000000      0.008712     -0.008542
# ..              ...           ...           ...           ...           ...
# 388             396      0.000000      0.000000      0.010715     -0.009610
# 389             397      0.000000      0.000000      0.011042     -0.009722
# 390             398      0.000000      0.000000      0.011339     -0.010946
# 391             399      0.000000      0.000000      0.011633     -0.010499
# 392             400      0.000000      0.000000      0.011722     -0.010591
#
# ...

# %%
landmark_y_columns_front = df_front.filter(regex='Landmark_\d+_Y')
landmark_y_columns_front
# Out:
#      Landmark_0_Y  Landmark_1_Y  Landmark_2_Y  Landmark_3_Y  Landmark_4_Y  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1       -0.101806      0.163287      0.087615      0.177434     -0.085946
# 2       -0.101665      0.163824      0.088474      0.177663     -0.085618
# 3       -0.102685      0.164692      0.089182      0.177882     -0.086377
# 4       -0.105106      0.165810      0.090070      0.178812     -0.089574
# ..            ...           ...           ...           ...           ...
# 388     -0.139480      0.249114      0.168466      0.276816     -0.141152
# 389     -0.139031      0.253828      0.171233      0.279545     -0.141438
# 390     -0.139012      0.258249      0.172071      0.281824     -0.142284
# 391     -0.138654      0.260583      0.171671      0.279046     -0.142439
# 392     -0.138512      0.260264      0.171498      0.275932     -0.142510
#
#      Landmark_5_Y  Landmark_6_Y  Landmark_7_Y  Landmark_8_Y  Landmark_9_Y  \
# ...

# %%
landmark_y_columns_side = df_side.filter(regex='Landmark_\d+_Y')
landmark_y_columns_side
# Out:
#      Landmark_0_Y  Landmark_1_Y  Landmark_2_Y  Landmark_3_Y  Landmark_4_Y  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1        0.041629      0.370292     -0.015605      0.379173      0.053247
# 2        0.010164      0.341008     -0.054089      0.371071     -0.000043
# 3       -0.014974      0.324715     -0.048759      0.368682     -0.028606
# 4       -0.024800      0.322879     -0.047123      0.369763     -0.043779
# ..            ...           ...           ...           ...           ...
# 267     -0.002849      0.257376     -0.008371      0.340142      0.019854
# 268     -0.002125      0.258914     -0.006686      0.181865      0.022041
# 269     -0.001003      0.264704     -0.002364      0.208923      0.025570
# 270     -0.004054      0.259281     -0.052682      0.211396      0.023819
# 271      0.000203      0.255241     -0.045334      0.210731      0.027949
#
#      Landmark_5_Y  Landmark_6_Y  Landmark_7_Y  Landmark_8_Y  Landmark_9_Y  \
# ...

# %%
merged_df_walking_y =

# %%
landmark_x_columns.fillna(0, inplace=True)

# landmark_y_columns.fillna(0, inplace=True)
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\pandas\core\frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#        Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0    57469964027405      0.052122      0.184667     -0.031033      0.185627
# 1                 2      0.000000      0.000000      0.009360     -0.007728
# 2                 3      0.000000      0.000000      0.009326     -0.008020
# 3                 4      0.000000      0.000000      0.009107     -0.008286
# 4                 5      0.000000      0.000000      0.008712     -0.008542
# ..              ...           ...           ...           ...           ...
# 388             396      0.000000      0.000000      0.010715     -0.009610
# ...

# %%
landmark_x_columns.describe()
# Out:
#        Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# count  3.930000e+02    393.000000    393.000000    393.000000    393.000000
# mean   1.462340e+11      0.000133      0.000470      0.001914     -0.010042
# std    2.898976e+12      0.002629      0.009315      0.010838      0.010518
# min    2.000000e+00      0.000000      0.000000     -0.040043     -0.031143
# 25%    1.000000e+02      0.000000      0.000000     -0.007721     -0.011356
# 50%    2.050000e+02      0.000000      0.000000      0.008470     -0.009381
# 75%    3.030000e+02      0.000000      0.000000      0.010246     -0.008299
# max    5.746996e+13      0.052122      0.184667      0.016790      0.185627
#
#        Landmark_5_X  Landmark_6_X  Landmark_7_X  Landmark_8_X  Landmark_9_X  \
# count    393.000000    393.000000    393.000000    393.000000    393.000000
# mean       0.002480     -0.009837      0.002944     -0.009619     -0.000105
# ...

# %%
side_landmark_x_columns = df_side.filter(regex='Landmark_\d+_X')
side_landmark_x_columns
# Out:
#          Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0    9175236225128170     -0.067215      0.349202     -0.057309      0.352014
# 1                   2      0.000000      0.000000      0.003897     -0.020056
# 2                   3      0.000000      0.000000      0.001755     -0.022411
# 3                   4      0.000000      0.000000      0.001272     -0.022627
# 4                   5      0.000000      0.000000      0.003532     -0.022217
# ..                ...           ...           ...           ...           ...
# 267               268      0.000000      0.000000     -0.000580     -0.017504
# 268               269      0.000000      0.000000      0.001340     -0.017669
# 269               270      0.000000      0.000000      0.003874     -0.016793
# 270               271      0.000000      0.000000      0.006410     -0.016121
# 271               272      0.000000      0.000000      0.008466     -0.014919
#
# ...

# %%
merged_df_walking_x = pd.concat([landmark_x_columns, side_landmark_x_columns], axis=0)
merged_df_walking_x
# Out:
#        Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  Landmark_4_X  \
# 0    57469964027405      0.052122      0.184667     -0.031033      0.185627
# 1                 2      0.000000      0.000000      0.009360     -0.007728
# 2                 3      0.000000      0.000000      0.009326     -0.008020
# 3                 4      0.000000      0.000000      0.009107     -0.008286
# 4                 5      0.000000      0.000000      0.008712     -0.008542
# ..              ...           ...           ...           ...           ...
# 267             268      0.000000      0.000000     -0.000580     -0.017504
# 268             269      0.000000      0.000000      0.001340     -0.017669
# 269             270      0.000000      0.000000      0.003874     -0.016793
# 270             271      0.000000      0.000000      0.006410     -0.016121
# 271             272      0.000000      0.000000      0.008466     -0.014919
#
# ...

# %%
merged_df_walking_y = pd.merge(landmark_y_columns_front, landmark_y_columns_side, left_index=True, right_index=True, suffixes=('', '_Side'))
merged_df_walking_y.fillna(0, inplace = True)
merged_df_walking_y
# Out:
#      Landmark_0_Y  Landmark_1_Y  Landmark_2_Y  Landmark_3_Y  Landmark_4_Y  \
# 0        0.000000      0.000000      0.000000      0.000000      0.000000
# 1       -0.101806      0.163287      0.087615      0.177434     -0.085946
# 2       -0.101665      0.163824      0.088474      0.177663     -0.085618
# 3       -0.102685      0.164692      0.089182      0.177882     -0.086377
# 4       -0.105106      0.165810      0.090070      0.178812     -0.089574
# ..            ...           ...           ...           ...           ...
# 267      0.033124      0.164363     -0.035715      0.144147      0.021722
# 268      0.026714      0.162422     -0.028223      0.153240      0.017308
# 269      0.019674      0.164068     -0.008385      0.170562      0.011444
# 270     -0.014790      0.163779      0.025803      0.179071     -0.018953
# 271     -0.024371      0.163693      0.047219      0.181229     -0.031038
#
#      Landmark_5_Y  Landmark_6_Y  Landmark_7_Y  Landmark_8_Y  Landmark_9_Y  \
# ...

# %%
# 각 landmark의 X,Y 좌표의 평균 계산
walking_mean_x = merged_df_walking_x.mean().values
walking_mean_y = merged_df_walking_y.mean().values

# 각 landmark의 X,Y 좌표의 표준편차 계산
walking_std_x = merged_df_walking_x.std().values
walking_std_y = merged_df_walking_y.std().values

# %%
walking_mean_x
# Out:
# array([ 1.38837687e+13, -2.26958354e-05,  8.02810927e-04,  6.32507696e-04,
#        -1.39584121e-02,  1.34389658e-03, -1.36544413e-02,  2.03116356e-03,
#        -1.35921422e-02, -2.05467275e-03, -1.28211298e-02, -3.50330373e-03,
#        -1.26888659e-02, -4.69256204e-03, -1.24677070e-02,  1.91202871e-03,
#        -7.53093793e-03, -5.52205415e-03, -6.19296438e-03,  2.18730036e-03,
#         1.67057276e-02, -2.44676830e-03,  1.55356139e-02, -2.17519115e-03,
#         7.43424666e-02, -2.43198082e-03,  7.50548234e-02, -4.95341416e-05,
#         1.92476769e-01,  1.14454835e-03,  1.98793653e-01,  4.05287364e-03,
#         2.74198969e-01])

# %%
file_path = "c:/Users/bluecom001/Desktop/pose_estimation/webcam_landmarks.xlsx"
df_standing = pd.read_excel(file_path)
df_standing.head()
# Out:
#    Frame  Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  \
# 0     78      0.429216      1.204688      0.589662      1.497391
# 1      0      0.489626      0.558973      0.498845      0.536821
# 2      0      0.486095      0.557073      0.497487      0.535835
# 3      0      0.484957      0.554869      0.496703      0.534246
# 4      0      0.485029      0.552930      0.496753      0.533095
#
#    Landmark_4_X  Landmark_5_X  Landmark_6_X  Landmark_7_X  Landmark_8_X  ...  \
# 0      0.449896      1.515296      0.596087      1.774190      0.464520  ...
# 1      0.506439      0.537696      0.513772      0.538847      0.473755  ...
# 2      0.505516      0.536841      0.513365      0.538123      0.470570  ...
# 3      0.504915      0.535266      0.513071      0.536592      0.469123  ...
# 4      0.505017      0.534166      0.513175      0.535524      0.469473  ...
#
#    Landmark_23_Y  Landmark_24_Y  Landmark_25_Y  Landmark_26_Y  Landmark_27_Y  \
# ...

# %%
df_standing.describe()
# Out:
#             Frame  Landmark_0_X  Landmark_1_X  Landmark_2_X  Landmark_3_X  \
# count  194.000000    194.000000    194.000000    194.000000    194.000000
# mean     0.402062      0.478808      0.592462      0.483350      0.565750
# std      5.600074      0.052598      0.049500      0.045066      0.069690
# min      0.000000      0.401371      0.550892      0.406247      0.532320
# 25%      0.000000      0.434187      0.570584      0.451560      0.542176
# 50%      0.000000      0.474874      0.588123      0.479052      0.560948
# 75%      0.000000      0.518231      0.603354      0.515024      0.571762
# max     78.000000      0.564535      1.204688      0.589662      1.497391
#
#        Landmark_4_X  Landmark_5_X  Landmark_6_X  Landmark_7_X  Landmark_8_X  \
# count    194.000000    194.000000    194.000000    194.000000    194.000000
# mean       0.485401      0.565751      0.488677      0.567256      0.474580
# ...

# %%
landmark_x_columns_stand = df_standing.filter(regex='Landmark_\d+_X')
landmark_y_columns_stand = df_standing.filter(regex='Landmark_\d+_Y')

# %%
stand_mean_x = landmark_x_columns_stand.mean().values
stand_mean_y = landmark_y_columns_stand.mean().values

# %%
walking_mean_x
# Out:
# array([ 1.38837687e+13, -2.26958354e-05,  8.02810927e-04,  6.32507696e-04,
#        -1.39584121e-02,  1.34389658e-03, -1.36544413e-02,  2.03116356e-03,
#        -1.35921422e-02, -2.05467275e-03, -1.28211298e-02, -3.50330373e-03,
#        -1.26888659e-02, -4.69256204e-03, -1.24677070e-02,  1.91202871e-03,
#        -7.53093793e-03, -5.52205415e-03, -6.19296438e-03,  2.18730036e-03,
#         1.67057276e-02, -2.44676830e-03,  1.55356139e-02, -2.17519115e-03,
#         7.43424666e-02, -2.43198082e-03,  7.50548234e-02, -4.95341416e-05,
#         1.92476769e-01,  1.14454835e-03,  1.98793653e-01,  4.05287364e-03,
#         2.74198969e-01])

# %%
print(stand_mean_x.shape)
print(walking_mean_x.shape)
# Out:
# (33,)
# (33,)

# %%
threshold_mean_x = (stand_mean_x + walking_mean_x) / 2
threshold_mean_x
# Out:
# array([6.94188435e+12, 2.96219747e-01, 2.42076355e-01, 2.83191308e-01,
#        2.35721093e-01, 2.83547316e-01, 2.37511416e-01, 2.84643626e-01,
#        2.30494125e-01, 2.82953277e-01, 2.29897518e-01, 2.82581993e-01,
#        2.28433188e-01, 2.82398274e-01, 2.40219203e-01, 2.92694778e-01,
#        2.30495888e-01, 2.90798263e-01, 2.39820023e-01, 3.10914702e-01,
#        2.45580658e-01, 3.09601937e-01, 2.67260770e-01, 3.78746795e-01,
#        2.61152811e-01, 3.81085199e-01, 3.04401322e-01, 4.85393996e-01,
#        3.12957993e-01, 4.94447949e-01, 3.76796392e-01, 5.66652539e-01,
#        3.42849491e-01])
