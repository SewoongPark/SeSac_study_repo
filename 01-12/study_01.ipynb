# %% [markdown]
# ### **고전, 추론 통계**
# * **가설 검증을 사용하는 이유:** 데이터 셋이 분석할 가치가 있는지의 여부 확인
#     * 예) 카이제곱 검정(p-value, t-value), 수식은 큰 의미가 없다
#     * 하지만 빅데이터에서는 p-value가 5% 미만으로 나오기 때문에 가설 검증을 하지 않는다.
#     * 예외로 정형 데이터 분석에서는 고전 모델을 사용한 가설 검증을 해야함
# * **양적 자료(연속형 변수)**: 기술 통계 확인
# * **질적 자료(범주형 변수)**: 발생 빈도 확인

# %% [markdown]
# ##### **귀무가설과 대립가설**
# * 측정한 표본의 통계량이 모집단을 대표할 수 있는지의 여부를 확인
#     * ex) 슬관절염의 발생 빈도와 연령대의 관계
#     * 통계량이 임계 범위내에 들어오면 대립 가설 채택

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
answer = list(df.loc[df['dislikes'] > df['likes']].channelTitle.unique())
print(answer)
# Out:
# ['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang', '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담', 'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈', '나혼자산다 STUDIO', 'Gen.G esports']

# %%
from glob import glob
import pandas as pd

dataPath = 'C:/data/dataList/happy/*.xlsx'
dataList = glob('C:/data/dataList/happy/*.xlsx')
file_name=[]
for num in range(len(dataList)):
    file = dataList[num]
    file_name += [file.split('_')[-1].split(".")[0]]

# %%
fileList = []
for rile in file_name:
    file = pd.read_excel(dataPath[:-6]+ "대한민국행복지도" + "_" + rile + ".xlsx")

# %%
df_health = file

# %%
df_health[(df_health['평균'] > 0.8)|(df_health['평균']<0.3)]['시도'].value_counts()
df_health[(df_health['평균'] > 0.8)|(df_health['평균']<0.3)]['시도'].str.contains('특별').tail()
df_health[(df_health['평균'] > 0.8)|(df_health['평균']<0.3)]['시도'].str.contains('특별')
# Out:
# 219    False
# 220    False
# 221    False
# 223    False
# 226    False
# Name: 시도, dtype: bool

# %%
df_health[(df_health['시도'] == '서울특별시') & (df_health['구군'] == '중구')]
# Out:
#    No     시도  구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  도시지역 중 '녹지지역 비율'  \
# 1   2  서울특별시  중구  0.2865    0.1077                 0.6957            0.0013
#
#    미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 1             0.6617                 0.0

# %%
df_health[(df_health['시도'] == '서울특별시')&(df_health['평균']> 0.5 )].tail()
# Out:
#     No     시도   구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  도시지역 중 '녹지지역 비율'  \
# 9   10  서울특별시  도봉구  0.5545    0.2103                 0.7324            0.2838
# 10  11  서울특별시  노원구  0.6470    0.2926                 0.7293            0.3969
# 15  16  서울특별시  강서구  0.5817    0.2205                 0.7214            0.3136
# 21  22  서울특별시  서초구  0.5075    0.3190                 0.7191            0.3586
# 23  24  서울특별시  송파구  0.5124    0.2002                 0.7225            0.0589
#
#     미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 9              0.4556              0.8339
# 10             0.6509              0.8083
# 15             0.5723              0.7947
# 21             0.6178              0.3174
# 23             0.6188              0.7504

# %%
df_health[df_health['시도'].str.contains('특별')]
df_health[(df_health['평균']>0.8) | (df_health['평균']>0.8)].head()
# Out:
#       No     시도   구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  \
# 40    41  부산광역시  기장군  0.8287    0.4357                 0.6411
# 57    58  인천광역시  강화군  0.8149    0.4121                 0.6978
# 104  105    경기도  가평군  0.8264    0.8789                 0.6586
# 105  106    경기도  양평군  0.9072    0.9539                 0.6805
# 115  116    강원도  영월군  0.8183    0.9629                 0.6899
#
#      도시지역 중 '녹지지역 비율'  미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 40             0.8444             0.9028              0.7657
# 57             0.8181             0.7736              0.8339
# 104            0.9010             0.7332              0.4090
# 105            0.9056             0.4556              0.9011
# 115            0.7700             0.3314              0.7947

# %% [markdown]
# ``

# %%
교육 = pd.read_excel(file)[['시도','구군','평균']]
교육 = pd.read_excel(file).iloc[:,1:4]
교육
# Out:
#           시도    구군      평균
# 0      서울특별시   종로구  0.4637
# 1      서울특별시    중구  0.2865
# 2      서울특별시   용산구  0.5030
# 3      서울특별시   성동구  0.4196
# 4      서울특별시   광진구  0.4992
# ..       ...   ...     ...
# 224     경상남도   함양군  0.7717
# 225     경상남도   거창군  0.7998
# 226     경상남도   합천군  0.9117
# 227  제주특별자치도   제주시  0.6842
# 228  제주특별자치도  서귀포시  0.6842
#
# [229 rows x 3 columns]

# %%
for num in 교육['시도']:
 tmp = df_health[df_health['시도']==num]
 tmp_file = tmp.to_csv(dataPath[:-6] + num + ".csv", index=False, encoding='utf-8')

# %%
df_health['시군구'] = df_health['시도'] + "_" + df_health['구군'] 
df_health = df_health[['시도', '구군','평균','시군구']]

# %% [markdown]
# **속도 향상: 람다 함수와 리스트 컴프리헨션**
# * 람다 함수의 특징: 리스트를 사용하지 않기 때문에 속도가 빠름
# * 간접 호출이 아니라 **직접 호출 방식**

# %%
result = [ '상' if x > 0.5 else '하' for x in df_health['평균']]
df_health['비고'] = df_health['평균'].apply(lambda row : '상' if row > 0.5 else '하')
df_health.head()
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       시도   구군      평균        시군구 비고
# 0  서울특별시  종로구  0.4637  서울특별시_종로구  하
# 1  서울특별시   중구  0.2865   서울특별시_중구  하
# 2  서울특별시  용산구  0.5030  서울특별시_용산구  상
# 3  서울특별시  성동구  0.4196  서울특별시_성동구  하
# 4  서울특별시  광진구  0.4992  서울특별시_광진구  하

# %%
df = df_health.iloc[:,:-2].copy()
df['비고'] = 0

def insert_val(row):
    if row > 0.5:
        return '상'
    else:
        return '하'
    
for cnt, x in enumerate(df['평균']):
    df['비고']['cnt'] = insert_val(x)
df
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#           시도    구군      평균  비고
# 0      서울특별시   종로구  0.4637   0
# 1      서울특별시    중구  0.2865   0
# 2      서울특별시   용산구  0.5030   0
# 3      서울특별시   성동구  0.4196   0
# 4      서울특별시   광진구  0.4992   0
# ..       ...   ...     ...  ..
# 224     경상남도   함양군  0.7717   0
# 225     경상남도   거창군  0.7998   0
# 226     경상남도   합천군  0.9117   0
# 227  제주특별자치도   제주시  0.6842   0
# 228  제주특별자치도  서귀포시  0.6842   0
#
# [229 rows x 4 columns]

# %%
dataList
# Out:
# ['C:/data/dataList/happy\\대한민국행복지도_건강.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_경제.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_관계및사회참여.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_교육.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_삶의만족도.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_안전.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_여가.xlsx',
#  'C:/data/dataList/happy\\대한민국행복지도_환경.xlsx']

# %%
df_health = pd.read_excel(dataList[0])
df_econo = pd.read_excel(dataList[1])
df_relation = pd.read_excel(dataList[2])
df_edu = pd.read_excel(dataList[3])
df_life = pd.read_excel(dataList[4])
df_safe = pd.read_excel(dataList[5])
df_leisure = pd.read_excel(dataList[6])
df_environ = pd.read_excel(dataList[7])

# %%
df_happy = pd.read_excel(r"C:\data\dataList\대한민국행복지도_삶의만족도.xlsx")

# %%
from pandas import *

# %%
city = list(df_happy['시도'].unique())
happy_merge = pd.DataFrame({"시도":city})
happy_merge
# Out:
#          시도
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16  제주특별자치도

# %%
life = df_happy['삶의 만족도'].groupby(df_happy['시도']).mean()
happy_merge = pd.merge(happy_merge, life, on="시도")
happy_merge
# Out:
#          시도    삶의 만족도
# 0     서울특별시  0.490972
# 1     부산광역시  0.362081
# 2     대구광역시  0.363988
# 3     인천광역시  0.411480
# 4     광주광역시  0.484480
# 5     대전광역시  0.407580
# 6     울산광역시  0.471980
# 7   세종특별자치시  0.907700
# 8       경기도  0.426023
# 9       강원도  0.619506
# 10     충청북도  0.410100
# 11     충청남도  0.553100
# 12     전라북도  0.608193
# 13     전라남도  0.547709
# 14     경상북도  0.502223
# 15     경상남도  0.530794
# 16  제주특별자치도  0.711300

# %%
health = df_health['평균'].groupby(df_health['시도']).mean()
happy_merge = pd.merge(happy_merge, health.rename('건강'), on="시도")
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강
# 0  서울특별시  0.490972  0.569532
# 1  부산광역시  0.362081  0.511906
# 2  대구광역시  0.363988  0.482325
# 3  인천광역시  0.411480  0.339620
# 4  광주광역시  0.484480  0.632300

# %%
safe = df_safe['평균'].groupby(by=df_safe['시도']).mean()
happy_merge = pd.merge(happy_merge, safe.rename("안전"), on="시도")
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전
# 0  서울특별시  0.490972  0.569532  0.552256
# 1  부산광역시  0.362081  0.511906  0.404875
# 2  대구광역시  0.363988  0.482325  0.358429
# 3  인천광역시  0.411480  0.339620  0.421020
# 4  광주광역시  0.484480  0.632300  0.266440

# %%
environ = df_environ['평균'].groupby(df_environ['시도']).mean()
happy_merge = pd.merge(happy_merge, environ.rename("환경"), on="시도")
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480

# %%
econo = df_econo['평균'].groupby(df_econo['시도']).mean()
happy_merge = pd.merge(happy_merge, econo.rename("경제"), on="시도")
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경        경제
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380

# %%
edu = df_edu['평균'].groupby(df_edu['시도']).mean()
relation = df_relation['평균'].groupby(df_relation['시도']).mean()
leisure = df_leisure['평균'].groupby(df_leisure['시도']).mean()

# %%
happy_merge = pd.merge(happy_merge, edu.rename("교육"), on="시도")
happy_merge = pd.merge(happy_merge, relation.rename("관계"), on="시도")
happy_merge = pd.merge(happy_merge, leisure.rename("여가"), on="시도")

# %%
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경        경제        교육  \
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
#
#          관계        여가
# 0  0.390656  0.286732
# 1  0.294719  0.153587
# 2  0.407486  0.234925
# 3  0.504920  0.244590
# 4  0.637800  0.454980

# %%
print(df_life['삶의 만족도'].mean())
print(happy_merge['삶의 만족도'].mean())
# Out:
# 0.4937618421052632
# 0.5181887062335198

# %%
print(happy_merge['건강'].mean())
print(df_health['평균'].mean())
# Out:
# 0.4094014744072605
# 0.40443508771929826

# %%
happy_merge.isnull().sum()
# Out:
# 시도        0
# 삶의 만족도    0
# 건강        0
# 안전        0
# 환경        0
# 경제        0
# 교육        0
# 관계        0
# 여가        0
# dtype: int64

# %%
# 행복 지수 요소별 평균 확인
happy_merge.mean()
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 삶의 만족도    0.518189
# 건강        0.409401
# 안전        0.420882
# 환경        0.579406
# 경제        0.407635
# 교육        0.578653
# 관계        0.497632
# 여가        0.464910
# dtype: float64

# %%
# 시도별 평균 확인
happy_merge.mean(axis=1)
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0     0.461637
# 1     0.389815
# 2     0.422433
# 3     0.418799
# 4     0.520068
# 5     0.497017
# 6     0.532900
# 7     0.521288
# 8     0.472481
# 9     0.526015
# 10    0.500400
# 11    0.508128
# 12    0.488729
# 13    0.500111
# 14    0.436254
# 15    0.482856
# 16    0.559075
# dtype: float64

# %%
happy_merge.set_index('시도').mean(axis=1)
# Out:
# 시도
# 서울특별시      0.461637
# 부산광역시      0.389815
# 대구광역시      0.422433
# 인천광역시      0.418799
# 광주광역시      0.520068
# 대전광역시      0.497017
# 울산광역시      0.532900
# 세종특별자치시    0.521288
# 경기도        0.472481
# 강원도        0.526015
# 충청북도       0.500400
# 충청남도       0.508128
# 전라북도       0.488729
# 전라남도       0.500111
# 경상북도       0.436254
# 경상남도       0.482856
# 제주특별자치도    0.559075
# dtype: float64

# %%
happy_merge.corr()
# Out:
#           삶의 만족도        건강        안전        환경        경제        교육        관계  \
# 삶의 만족도  1.000000 -0.570466 -0.191709  0.572262 -0.057815 -0.113522  0.519122
# 건강     -0.570466  1.000000 -0.210138 -0.357841  0.071809  0.242186 -0.175048
# 안전     -0.191709 -0.210138  1.000000 -0.124581 -0.142781 -0.519065 -0.444827
# 환경      0.572262 -0.357841 -0.124581  1.000000 -0.716187 -0.146646  0.169838
# 경제     -0.057815  0.071809 -0.142781 -0.716187  1.000000  0.451395  0.298562
# 교육     -0.113522  0.242186 -0.519065 -0.146646  0.451395  1.000000  0.462585
# 관계      0.519122 -0.175048 -0.444827  0.169838  0.298562  0.462585  1.000000
# 여가      0.497880 -0.405151  0.382730  0.494416 -0.367461 -0.070109  0.216653
#
#               여가
# 삶의 만족도  0.497880
# 건강     -0.405151
# 안전      0.382730
# 환경      0.494416
# 경제     -0.367461
# 교육     -0.070109
# 관계      0.216653
# 여가      1.000000

# %%
# !rm ~/.cache/matplotlib -rf
# Out:
# 'rm'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.figure(figsize=(15, 6))
items = list(happy_merge.columns[1:9])

for a in items:
    chart_data = happy_merge[a]
    plt.plot(chart_data, marker='o', label=a)

font_path = "C:/Users/bluecom001/Downloads/nanum-all/나눔 글꼴/나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf"
font_prop = fm.FontProperties(fname=font_path, size=10).get_name()
plt.rcParams['font.family'] = font_prop

plt.xlabel('시도')
plt.ylabel('수치')
plt.xticks(range(17), happy_merge['시도'], fontsize = 8)
plt.grid()
plt.legend(prop=font_prop)
plt.show()
# Out:
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
from numpy import *

happy_merge.plot(kind='bar', xlabel='city', ylabel='figure',figsize=(20,20),
                 grid=True,subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'삶의 만족도'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'건강'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'안전'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'환경'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'경제'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'교육'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'관계'}, xlabel='city', ylabel='figure'>,
#        <AxesSubplot:title={'center':'여가'}, xlabel='city', ylabel='figure'>],
#       dtype=object)
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# c:\Users\bluecom001\miniconda3\envs\mp\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49334 (\N{HANGUL SYLLABLE SALM}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df_happy
# Out:
#       No       시도    구군  삶의 만족도
# 0      1    서울특별시   종로구  0.4437
# 1      2    서울특별시    중구  0.4976
# 2      3    서울특별시   용산구  0.6161
# 3      4    서울특별시   성동구  0.4729
# 4      5    서울특별시   광진구  0.4041
# ..   ...      ...   ...     ...
# 224  225     경상남도   함양군  0.9565
# 225  226     경상남도   거창군  0.6163
# 226  227     경상남도   합천군  0.8057
# 227  228  제주특별자치도   제주시  0.7113
# 228  229  제주특별자치도  서귀포시  0.7113
#
# [229 rows x 4 columns]

# %%
import seaborn as sns
plt.figure(figsize=(15,13))
plt.rc('axes', unicode_minus=False)
correlation_mat = happy_merge.corr()
upp_mat = triu(correlation_mat)

sns.heatmap(correlation_mat, mask=upp_mat,annot=True)
plt.show()

# %%
from glob import glob
import pandas as pd

fileList=glob('c:/data/dataList/happy/*.xlsx')
file=fileList[0]
df=pd.read_excel(file).iloc[:,1:4]
happy=pd.DataFrame({'시도': 
                          df['시도'].unique()})
#print(happy[:3])  #시도데이터를 그룹으로 제작



for file in fileList:
    print(file)
    colName=file.split('_')[1].split('.')[0]
    df=pd.read_excel(file).iloc[:,1:4]
    df.columns=['시도','군구','평균']
    tmp=df['평균'].groupby(df['시도']).mean()
    happy=pd.merge(happy,tmp.rename(colName), on='시도')

happy
